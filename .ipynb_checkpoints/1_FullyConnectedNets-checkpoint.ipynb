# %% [markdown]
# # Fully-Connected Neural Nets
# I have implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was done using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.
#
# For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive derivative of loss with respect to outputs and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, I explored different update rules for optimization, and introduced Batch Normalization as a tool to more efficiently optimize deep networks.

# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from dl4cv.classifiers.fc_net import *
from dl4cv.data_utils import get_CIFAR10_data
from dl4cv.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# supress cluttering warnings in solutions
import warnings
warnings.filterwarnings('ignore')

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in data.items():
    print('%s: ' % k, v.shape)
# Out:
# X_train:  (48000, 3, 32, 32)
# y_train:  (48000,)
# X_val:  (1000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# # Affine layer: foward
# Open the file `dl4cv/layers.py` and have a look at the `affine_forward` function. It is defined there is to make this main file a bit clean

# %% [markdown]
# # Affine layer: backward
# Now have a look at `affine_backward` function. This will be used for back propagation between the layers

# %% [markdown]
# # ReLU layer: forward
# Implementation of the forward pass for the ReLU activation function is in in the `relu_forward` function.

# %% [markdown]
# # ReLU layer: backward
# As I have used ReLU activation function, its backward pass had to implemented. It has been done in the `relu_backward` function.

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, I have defined these as `affine_relu_forward` and `affine_relu_backward` functions.

# %% [markdown]
# # Loss layers: Softmax
# The softmax function has been defined in the end which will be used after the final layer

# %% [markdown]
# # Two-layer network
# I was trying to test two-layer network before going for more layers. Please open the file `dl4cv/classifiers/fc_net.py` and have a look at the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks which have been implemented afterwards

# %% [markdown]
# # Solver
# For better readabilty of the code and following a more modular design, for this assignment, I have logic for training models into a separate class.
#
# Open the file `dl4cv/solver.py` and have a look at it I have used use a `Solver` instance to train a `TwoLayerNet`

# %%
model = TwoLayerNet(hidden_dim=150, reg=1e-3, weight_scale=1e-3)
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
#pass
mod_data ={}
mod_data['X_train'] = data['X_train'] 
mod_data['X_val'] = data['X_val']
mod_data['y_train'] = data['y_train']
mod_data['y_val'] = data['y_val']
        
solver = Solver(model, mod_data)
solver.train()

##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 4800) loss: 2.304949
# (Epoch 0 / 10) train acc: 0.146000; val_acc: 0.126000
# (Iteration 11 / 4800) loss: 2.192078
# (Iteration 21 / 4800) loss: 2.120110
# (Iteration 31 / 4800) loss: 1.953598
# (Iteration 41 / 4800) loss: 1.955424
# (Iteration 51 / 4800) loss: 2.059948
# (Iteration 61 / 4800) loss: 1.884821
# (Iteration 71 / 4800) loss: 1.852713
# (Iteration 81 / 4800) loss: 1.917294
# (Iteration 91 / 4800) loss: 1.808693
# (Iteration 101 / 4800) loss: 1.947218
# (Iteration 111 / 4800) loss: 1.583780
# (Iteration 121 / 4800) loss: 1.539995
# (Iteration 131 / 4800) loss: 1.692396
# (Iteration 141 / 4800) loss: 1.647053
# (Iteration 151 / 4800) loss: 1.709595
# (Iteration 161 / 4800) loss: 1.751620
# (Iteration 171 / 4800) loss: 1.772085
# (Iteration 181 / 4800) loss: 1.734167
# (Iteration 191 / 4800) loss: 1.555612
# (Iteration 201 / 4800) loss: 1.793895
# (Iteration 211 / 4800) loss: 1.630944
# (Iteration 4571 / 4800) loss: 1.466081
# (Iteration 4581 / 4800) loss: 1.151305
# (Iteration 4591 / 4800) loss: 1.635064
# (Iteration 4601 / 4800) loss: 1.029248
# (Iteration 4611 / 4800) loss: 1.310801
# (Iteration 4621 / 4800) loss: 1.224103
# (Iteration 4631 / 4800) loss: 1.042714
# (Iteration 4641 / 4800) loss: 0.916542
# (Iteration 4651 / 4800) loss: 0.948632
# (Iteration 4661 / 4800) loss: 1.215219
# (Iteration 4671 / 4800) loss: 1.274189
# (Iteration 4681 / 4800) loss: 1.029296
# (Iteration 4691 / 4800) loss: 1.022645
# (Iteration 4701 / 4800) loss: 1.032255
# (Iteration 4711 / 4800) loss: 1.110739
# (Iteration 4721 / 4800) loss: 1.274841
# (Iteration 4731 / 4800) loss: 1.469631
# (Iteration 4741 / 4800) loss: 1.168427
# (Iteration 4751 / 4800) loss: 1.381476
# (Iteration 4761 / 4800) loss: 1.276891
# (Iteration 4771 / 4800) loss: 1.393028
# (Iteration 4781 / 4800) loss: 1.044733
# (Iteration 4791 / 4800) loss: 1.218157
# (Epoch 10 / 10) train acc: 0.580000; val_acc: 0.481000

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Since the two layer network worded, I then implemented a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `dl4cv/classifiers/fc_net.py`.
#
# Look at the the initialization, the forward pass, and the backward pass.

# %% [markdown]
# ## Sanity Check

# %% [markdown]
# As a sanity check, I tried to overfit a small dataset of 50 images on a three-layer network with 100 units in each hidden layer. Since I found that stochastic gradient descent parameter update is not effective as others, I implemented a few other and eventually stuck with 'sgd_momentum'

# %%
# TODO: Use a three-layer Net to overfit 50 training examples.
# Three-layer network means 2 hidden layers

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-2   # It was 1.0 originally
learning_rate = 1e-2  # It was 1.0 originally
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.343582
# (Epoch 0 / 20) train acc: 0.380000; val_acc: 0.134000
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.101000
# (Epoch 2 / 20) train acc: 0.480000; val_acc: 0.125000
# (Epoch 3 / 20) train acc: 0.600000; val_acc: 0.149000
# (Epoch 4 / 20) train acc: 0.620000; val_acc: 0.146000
# (Epoch 5 / 20) train acc: 0.520000; val_acc: 0.133000
# (Iteration 11 / 40) loss: 1.317583
# (Epoch 6 / 20) train acc: 0.620000; val_acc: 0.144000
# (Epoch 7 / 20) train acc: 0.840000; val_acc: 0.157000
# (Epoch 8 / 20) train acc: 0.840000; val_acc: 0.161000
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.143000
# (Epoch 10 / 20) train acc: 0.900000; val_acc: 0.169000
# (Iteration 21 / 40) loss: 0.293809
# (Epoch 11 / 20) train acc: 0.840000; val_acc: 0.185000
# (Epoch 12 / 20) train acc: 0.940000; val_acc: 0.184000
# (Epoch 13 / 20) train acc: 0.960000; val_acc: 0.175000
# (Epoch 14 / 20) train acc: 0.960000; val_acc: 0.179000
# (Epoch 15 / 20) train acc: 0.960000; val_acc: 0.173000
# (Iteration 31 / 40) loss: 0.098487
# (Epoch 16 / 20) train acc: 0.960000; val_acc: 0.174000
# (Epoch 17 / 20) train acc: 0.960000; val_acc: 0.173000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.173000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.177000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.176000

# %% [markdown]
# # Update rules
# I have shown the comparison between different update rules on a five layer net, each layer having 500 units

# %%
num_train = 4000
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum', 'adam']:
    print('running with ', update_rule)
    model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

    solver = Solver(model, small_data,
                    num_epochs=10, batch_size=100,
                    update_rule=update_rule,
                    optim_config={'learning_rate': 1e-3},
                    verbose=True)
    solvers[update_rule] = solver
    solver.train()
    print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
    plt.subplot(3, 1, 1)
    plt.plot(solver.loss_history, 'o', label=update_rule)
  
    plt.subplot(3, 1, 2)
    plt.plot(solver.train_acc_history, '-o', label=update_rule)

    plt.subplot(3, 1, 3)
    plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
    plt.subplot(3, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 400) loss: 2.466570
# (Epoch 0 / 10) train acc: 0.105000; val_acc: 0.083000
# (Iteration 11 / 400) loss: 2.325422
# (Iteration 21 / 400) loss: 2.308572
# (Iteration 31 / 400) loss: 2.362937
# (Epoch 1 / 10) train acc: 0.163000; val_acc: 0.136000
# (Iteration 41 / 400) loss: 2.276096
# (Iteration 51 / 400) loss: 2.243389
# (Iteration 61 / 400) loss: 2.255845
# (Iteration 71 / 400) loss: 2.226900
# (Epoch 2 / 10) train acc: 0.180000; val_acc: 0.167000
# (Iteration 81 / 400) loss: 2.195798
# (Iteration 91 / 400) loss: 2.275540
# (Iteration 101 / 400) loss: 2.256826
# (Iteration 111 / 400) loss: 2.137546
# (Epoch 3 / 10) train acc: 0.205000; val_acc: 0.196000
# (Iteration 121 / 400) loss: 2.166887
# (Iteration 131 / 400) loss: 2.143348
# (Iteration 141 / 400) loss: 2.182613
# (Iteration 151 / 400) loss: 2.139709
# (Epoch 4 / 10) train acc: 0.258000; val_acc: 0.208000
# (Iteration 161 / 400) loss: 2.105757
# (Iteration 171 / 400) loss: 2.157969
# (Iteration 181 / 400) loss: 2.069345
# (Iteration 191 / 400) loss: 2.124037
# (Epoch 5 / 10) train acc: 0.263000; val_acc: 0.229000
# (Iteration 201 / 400) loss: 2.097336
# (Iteration 211 / 400) loss: 2.066893
# (Iteration 221 / 400) loss: 1.899389
# (Iteration 231 / 400) loss: 2.015769
# (Epoch 6 / 10) train acc: 0.287000; val_acc: 0.233000
# (Iteration 241 / 400) loss: 2.073070
# (Iteration 251 / 400) loss: 1.957718
# (Iteration 261 / 400) loss: 2.041615
# (Iteration 271 / 400) loss: 2.154274
# (Epoch 7 / 10) train acc: 0.290000; val_acc: 0.235000
# (Iteration 281 / 400) loss: 1.942329
# (Iteration 291 / 400) loss: 2.019879
# (Iteration 301 / 400) loss: 2.092432
# (Iteration 311 / 400) loss: 1.974757
# (Epoch 8 / 10) train acc: 0.312000; val_acc: 0.248000
# (Iteration 321 / 400) loss: 1.982238
# (Iteration 331 / 400) loss: 1.979367
# (Iteration 341 / 400) loss: 2.040337
# (Iteration 351 / 400) loss: 1.906858
# (Iteration 31 / 400) loss: 1.730882
# (Epoch 1 / 10) train acc: 0.382000; val_acc: 0.312000
# (Iteration 41 / 400) loss: 1.719593
# (Iteration 51 / 400) loss: 1.631736
# (Iteration 61 / 400) loss: 1.685186
# (Iteration 71 / 400) loss: 1.580994
# (Epoch 2 / 10) train acc: 0.436000; val_acc: 0.330000
# (Iteration 81 / 400) loss: 1.481808
# (Iteration 91 / 400) loss: 1.582279
# (Iteration 101 / 400) loss: 1.507485
# (Iteration 111 / 400) loss: 1.618607
# (Epoch 3 / 10) train acc: 0.479000; val_acc: 0.345000
# (Iteration 121 / 400) loss: 1.312946
# (Iteration 131 / 400) loss: 1.396373
# (Iteration 141 / 400) loss: 1.305642
# (Iteration 151 / 400) loss: 1.195031
# (Epoch 4 / 10) train acc: 0.545000; val_acc: 0.356000
# (Iteration 161 / 400) loss: 1.238780
# (Iteration 171 / 400) loss: 1.349747
# (Iteration 181 / 400) loss: 1.409445
# (Iteration 191 / 400) loss: 1.360300
# (Epoch 5 / 10) train acc: 0.576000; val_acc: 0.371000
# (Iteration 201 / 400) loss: 1.153159
# (Iteration 211 / 400) loss: 1.163055
# (Iteration 221 / 400) loss: 1.068886
# (Iteration 231 / 400) loss: 1.090041
# (Epoch 6 / 10) train acc: 0.593000; val_acc: 0.340000
# (Iteration 241 / 400) loss: 1.013896
# (Iteration 251 / 400) loss: 0.982442
# (Iteration 261 / 400) loss: 1.138244
# (Iteration 271 / 400) loss: 0.973341
# (Epoch 7 / 10) train acc: 0.663000; val_acc: 0.361000
# (Iteration 281 / 400) loss: 1.046604
# (Iteration 291 / 400) loss: 0.938227
# (Iteration 301 / 400) loss: 1.047939
# (Iteration 311 / 400) loss: 0.730304
# (Epoch 8 / 10) train acc: 0.676000; val_acc: 0.357000
# (Iteration 321 / 400) loss: 0.749390
# (Iteration 331 / 400) loss: 0.760125
# (Iteration 341 / 400) loss: 0.680696
# (Iteration 351 / 400) loss: 1.038110
# (Epoch 9 / 10) train acc: 0.732000; val_acc: 0.361000
# (Iteration 361 / 400) loss: 0.951696
# (Iteration 371 / 400) loss: 1.073687
# (Iteration 381 / 400) loss: 0.788055
# (Iteration 391 / 400) loss: 0.641426
# (Epoch 10 / 10) train acc: 0.756000; val_acc: 0.378000

# %% [markdown]
# # Adam
# Adam [1] is an update rule that sets per-parameter learning rates by using a running average of the second moments of gradients.
#
# [1] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
num_train = 4000
learning_rates = {'adam': 1e-3}  
update_rule = 'adam'
print('running with ', update_rule)
model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)  #it was 5e-2 originally
solvers = {}
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}
solver = Solver(model, small_data,
              num_epochs=10, batch_size=100,
              update_rule=update_rule,
              optim_config={
                'learning_rate': learning_rates[update_rule]
              },
              verbose=True)
solvers[update_rule] = solver
solver.train()
print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
    plt.subplot(3, 1, 1)
    plt.plot(solver.loss_history, 'o', label=update_rule)
  
    plt.subplot(3, 1, 2)
    plt.plot(solver.train_acc_history, '-o', label=update_rule)

    plt.subplot(3, 1, 3)
    plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
    plt.subplot(3, 1, i)
    plt.legend(loc='upper center', ncol=4)
    
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  adam
# (Iteration 1 / 400) loss: 2.469360
# (Epoch 0 / 10) train acc: 0.134000; val_acc: 0.148000
# (Iteration 11 / 400) loss: 2.053211
# (Iteration 21 / 400) loss: 1.930519
# (Iteration 31 / 400) loss: 1.682540
# (Epoch 1 / 10) train acc: 0.350000; val_acc: 0.304000
# (Iteration 41 / 400) loss: 1.761698
# (Iteration 51 / 400) loss: 1.589918
# (Iteration 61 / 400) loss: 1.824691
# (Iteration 71 / 400) loss: 1.746892
# (Epoch 2 / 10) train acc: 0.434000; val_acc: 0.340000
# (Iteration 81 / 400) loss: 1.527302
# (Iteration 91 / 400) loss: 1.635365
# (Iteration 101 / 400) loss: 1.561504
# (Iteration 111 / 400) loss: 1.514827
# (Epoch 3 / 10) train acc: 0.517000; val_acc: 0.353000
# (Iteration 121 / 400) loss: 1.507595
# (Iteration 131 / 400) loss: 1.339763
# (Iteration 141 / 400) loss: 1.407802
# (Iteration 151 / 400) loss: 1.420209
# (Epoch 4 / 10) train acc: 0.559000; val_acc: 0.353000
# (Iteration 161 / 400) loss: 1.385077
# (Iteration 171 / 400) loss: 1.355711
# (Iteration 181 / 400) loss: 1.224505
# (Iteration 191 / 400) loss: 1.084456
# (Epoch 5 / 10) train acc: 0.570000; val_acc: 0.372000
# (Iteration 201 / 400) loss: 1.179059
# (Iteration 211 / 400) loss: 1.114055
# (Iteration 221 / 400) loss: 1.308466
# (Iteration 231 / 400) loss: 1.239397
# (Epoch 6 / 10) train acc: 0.603000; val_acc: 0.354000
# (Iteration 241 / 400) loss: 0.989926
# (Iteration 251 / 400) loss: 1.291598
# (Iteration 261 / 400) loss: 0.918932
# (Iteration 271 / 400) loss: 0.941274
# (Epoch 7 / 10) train acc: 0.678000; val_acc: 0.362000
# (Iteration 281 / 400) loss: 1.045912
# (Iteration 291 / 400) loss: 1.052680
# (Iteration 301 / 400) loss: 0.797673
# (Iteration 311 / 400) loss: 0.641882
# (Epoch 8 / 10) train acc: 0.699000; val_acc: 0.371000
# (Iteration 321 / 400) loss: 0.976224
# (Iteration 331 / 400) loss: 1.061864
# (Iteration 341 / 400) loss: 0.726176
# (Iteration 351 / 400) loss: 0.765815
# (Epoch 9 / 10) train acc: 0.711000; val_acc: 0.356000
# (Iteration 361 / 400) loss: 0.654441
# (Iteration 371 / 400) loss: 0.678778
# (Iteration 381 / 400) loss: 0.722405
# (Iteration 391 / 400) loss: 0.671451
# (Epoch 10 / 10) train acc: 0.748000; val_acc: 0.393000

# %% [markdown]
# # Train a good model on full data

# %%
solvers = {}
learning_rates = {'adam': 1e-3}   #it was 1e-3 originally
update_rule = 'adam'
print('running with ', update_rule)
best_model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)  #it was 5e-2 originally
big_data = {
  'X_train': data['X_train'],
  'y_train': data['y_train'],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}
solver = Solver(best_model, big_data,
              num_epochs=5, batch_size=100,
              update_rule=update_rule,
              optim_config={
                'learning_rate': learning_rates[update_rule]
              },
              verbose=True)
solvers[update_rule] = solver
solver.train()
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# running with  adam
# (Iteration 1 / 200) loss: 2.405092
# (Epoch 0 / 5) train acc: 0.160000; val_acc: 0.169000
# (Iteration 11 / 200) loss: 2.085473
# (Iteration 21 / 200) loss: 2.039231
# (Iteration 31 / 200) loss: 1.769308
# (Epoch 1 / 5) train acc: 0.356000; val_acc: 0.286000
# (Iteration 41 / 200) loss: 1.745687
# (Iteration 51 / 200) loss: 1.573601
# (Iteration 61 / 200) loss: 1.729736
# (Iteration 71 / 200) loss: 1.745267
# (Epoch 2 / 5) train acc: 0.437000; val_acc: 0.301000
# (Iteration 81 / 200) loss: 1.672513
# (Iteration 91 / 200) loss: 1.757310
# (Iteration 101 / 200) loss: 1.499351
# (Iteration 111 / 200) loss: 1.371322
# (Epoch 3 / 5) train acc: 0.496000; val_acc: 0.353000
# (Iteration 121 / 200) loss: 1.499811
# (Iteration 131 / 200) loss: 1.298447
# (Iteration 141 / 200) loss: 1.317008
# (Iteration 151 / 200) loss: 1.556594
# (Epoch 4 / 5) train acc: 0.551000; val_acc: 0.381000
# (Iteration 161 / 200) loss: 1.371283
# (Iteration 171 / 200) loss: 1.332301
# (Iteration 181 / 200) loss: 1.311596
# (Iteration 191 / 200) loss: 1.423218
# (Epoch 5 / 5) train acc: 0.586000; val_acc: 0.365000

# %% [markdown]
# # Test my model on validation set
# Run your best model on the validation and test sets. You should achieve above 48% accuracy on the validation set.

# %%
X_test = data['X_test']
X_val = data['X_val']
y_val = data['y_val']
y_test = data['y_test']

y_test_pred = np.argmax(best_model.loss(X_test), axis=1)
y_val_pred = np.argmax(best_model.loss(X_val), axis=1)
print('Validation set accuracy: ', (y_val_pred == y_val).mean())
print('Test set accuracy: ', (y_test_pred == y_test).mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c88acbc5510e> in <module>()
# ----> 1 X_test = data['X_test']
#       2 X_val = data['X_val']
#       3 y_val = data['y_val']
#       4 y_test = data['y_test']
#       5
#
# KeyError: 'X_test'

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.

# %%
from dl4cv.model_savers import save_fully_connected_net
save_fully_connected_net(best_model)

# %% [markdown]
# ## Scoring function
# We will score the model you have just saved based on the classification accuracy on our test dataset. The scoring function should represent the difficulty of obtaining a good test accuracy and should therefore give 0 points for worse results than random guessing, should be linear in a first regime and exponential beyond that. The onset of exponential growth depends on the problem. In that region you get twice as many points for an additional 10% accuracy.
#
# For this problem we specifically use the following scoring function:
#
# $$f(x) = \left\{
# 	\begin{array}{ll}
# 		0  & \mbox{if } x \leq 0.1 \\
# 		100x & \mbox{if } 0.1 < x \leq 0.5 \\
#         \left(\frac{50}{\exp(0.5 \ln(2)/0.1)}\right) \exp(x \ln(2)/0.1) & \mbox{if } 0.5 < x \leq 1
# 	\end{array}
# \right.$$
#
# The function can be plotted in the following cell.

# %%
from dl4cv.data_utils import scoring_function

x = np.linspace(0, 1, num=1000)
plt.plot(x, scoring_function(x, lin_exp_boundary=0.5, doubling_rate=0.1))
plt.title('Scoring Function')
plt.xlabel('Test Accuracy')
plt.ylabel('Score')
plt.show()
